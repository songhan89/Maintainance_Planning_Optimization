# %%
INSTANCE_ID = 'A_06'

# %%
import os
import json
import math
import time

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sko.GA import GA
from sko.tools import set_run_mode
from sko.AFSA import AFSA

# %%
def read_json(filename: str):
    """Read a json file and return data as a dict object"""

    print('Reading json file ' + filename + '...')
    f = open(filename, 'r')
    Instance = json.load(f)
    f.close()
    print('Done')

    return Instance

# %%
GAP = 0.05
TIME_LIMIT = 900 # 15 mins

RESOURCES_STR = 'Resources'
SEASONS_STR = 'Seasons'
INTERVENTIONS_STR = 'Interventions'
EXCLUSIONS_STR = 'Exclusions'
T_STR = 'T'
SCENARIO_NUMBER = 'Scenarios_number'
RESOURCE_CHARGE_STR = 'workload'
TMAX_STR = 'tmax'
DELTA_STR = 'Delta'
MAX_STR = 'max'
MIN_STR = 'min'
RISK_STR = 'risk'
START_STR = 'start'
QUANTILE_STR = "Quantile"
ALPHA_STR = "Alpha"

# COST_P_SCHEDULE = 200000
# COST_P_RESOURCE = 5
# COST_P_EXCLUDE = 5

optimal_value = {
    "A_01": 1767.8156110,
    "A_02": 4671.3766110,
    "A_03": 848.1786111,
    "A_04": 2085.8760540,
    "A_05": 635.2217857,
    "A_06": 590.6235989,
    "A_07": 2272.7822740,
    "A_08": 744.2932352,
    "A_09": 1507.2847840,
    "A_10": 2994.8487350,
    "A_11": 495.2557702,
    "A_12": 789.6349276,
    "A_13": 1998.6621620,
    "A_14": 2264.1243210,
    "A_15": 2268.5691500
}

COST_P_SCHEDULE = optimal_value[INSTANCE_ID]
COST_P_RESOURCE = optimal_value[INSTANCE_ID] / 3
COST_P_EXCLUDE = optimal_value[INSTANCE_ID] / 3

# %%
def compute_resources(Instance: dict):
    """Compute effective workload (i.e. resources consumption values) for every resource and every time step"""

    # Retrieve usefull infos
    Interventions = Instance[INTERVENTIONS_STR]
    T_max = Instance[T_STR]
    Resources = Instance[RESOURCES_STR]
    # Init resource usage dictionnary for each resource and time
    resources_usage = {}
    for resource_name in Resources.keys():
        resources_usage[resource_name] = np.zeros(T_max)
    # Compute value for each resource and time step
    for intervention_name, intervention in Interventions.items():
        # start time should be defined (already checked in scheduled constraint checker)
        if not START_STR in intervention:
            continue
        start_time = intervention[START_STR]
        start_time_idx = start_time - 1 #index of list starts at 0
        intervention_worload = intervention[RESOURCE_CHARGE_STR]
        intervention_delta = int(intervention[DELTA_STR][start_time_idx])
        # compute effective worload
        for resource_name, intervention_resource_worload in intervention_worload.items():
            for time in range(start_time_idx, start_time_idx + intervention_delta):
                # null values are not available
                if str(time+1) in intervention_resource_worload and str(start_time) in intervention_resource_worload[str(time+1)]:
                    resources_usage[resource_name][time] += intervention_resource_worload[str(time+1)][str(start_time)]

    return resources_usage

def compute_risk_distribution(Interventions: dict, T_max: int, scenario_numbers):
    """Compute risk distributions for all time steps, given the interventions starting times"""

    # Init risk table
    risk = [scenario_numbers[t] * [0] for t in range(T_max)]
    # Compute for each intervention independently
    for intervention in Interventions.values():
        # Retrieve Intervention's usefull infos
        intervention_risk = intervention[RISK_STR]
        # start time should be defined (already checked in scheduled constraint checker)
        if not START_STR in intervention:
            continue
        start_time = intervention[START_STR]
        start_time_idx = int(start_time) - 1 # index for list getter
        delta = int(intervention[DELTA_STR][start_time_idx])
        for time in range(start_time_idx, start_time_idx + delta):
            for i, additional_risk in enumerate(intervention_risk[str(time + 1)][str(start_time)]):
                risk[time][i] += additional_risk

    return risk

## Compute mean for each period
def compute_mean_risk(risk, T_max: int, scenario_numbers):
    """Compute mean risk values over each time period"""

    # Init mean risk
    mean_risk = np.zeros(T_max)
    # compute mean
    for t in range(T_max):
        mean_risk[t] = sum(risk[t]) / scenario_numbers[t]

    return mean_risk

## Compute quantile for each period
def compute_quantile(risk, T_max: int, scenario_numbers, quantile):
    """Compute Quantile values over each time period"""

    # Init quantile
    q = np.zeros(T_max)
    for t in range(T_max):
        risk[t].sort()
        q[t] = risk[t][int(np.ceil(scenario_numbers[t] * quantile))-1]

    return q

## Compute total objective
def compute_objective(Instance: dict):
    """Compute total objectives (mean and expected excess)"""

    # Retrieve usefull infos
    T_max = Instance[T_STR]
    scenario_numbers = Instance[SCENARIO_NUMBER]
    Interventions = Instance[INTERVENTIONS_STR]
    quantile = Instance[QUANTILE_STR]
    # Retrieve risk final distribution
    risk = compute_risk_distribution(Interventions, T_max, scenario_numbers)
    # Compute mean risk
    mean_risk = compute_mean_risk(risk, T_max, scenario_numbers)
    # Compute quantile
    quantile = compute_quantile(risk, T_max, scenario_numbers, quantile)

    # Usefull infos
    alpha = Instance[ALPHA_STR]
    q = Instance[QUANTILE_STR]
    obj_1 = np.mean(mean_risk)
    tmp = np.zeros(len(quantile))
    obj_2 = np.mean(np.max(np.vstack((quantile - mean_risk, tmp)), axis=0))
    obj_tot = alpha * obj_1 + (1-alpha)*obj_2

    return obj_tot

# %%
## Launch each Constraint checks
def compute_penalty(Instance: dict):
    """Run all constraint checks"""

    total_penalty_cost = 0
    # Schedule constraints
    total_penalty_cost += COST_P_SCHEDULE * check_schedule(Instance)
    # Resources constraints
    total_penalty_cost += COST_P_RESOURCE * check_resources(Instance)
    # Exclusions constraints
    total_penalty_cost += COST_P_EXCLUDE * check_exclusions(Instance)

    return total_penalty_cost

## Schedule constraints: §4.1 in model description
def check_schedule(Instance: dict):
    """Check schedule constraints"""

    # Continuous interventions: §4.1.1
    #   This constraint is implicitly checked by the resource computation:
    #   computation is done under continuity hypothesis, and resource bounds will ensure the feasibility
    # Checks is done on each Intervention
    count = 0
    Interventions = Instance[INTERVENTIONS_STR]
    for intervention_name, intervention in Interventions.items():
        # Interventions are planned once: §4.1.2
        #   assert a starting time has been assigned to the intervention
        if not START_STR in intervention:
            print('ERROR: Schedule constraint 4.1.2: Intervention ' + intervention_name + ' has not been scheduled.')
            continue
        # Starting time validity: no explicit constraint
        start_time = intervention[START_STR]
        horizon_end = Instance[T_STR]
        if not (1 <= start_time <= horizon_end):
            count += 1
        # No work left: §4.1.3
        #   assert intervention is not ongoing after time limit or end of horizon
        time_limit = int(intervention[TMAX_STR])
        if time_limit < start_time:
            count += 1

    return count

## Resources constraints: §4.2 in model description
def check_resources(Instance: dict):
    """Check resources constraints"""

    count = 0
    T_max = Instance[T_STR]
    Resources = Instance[RESOURCES_STR]
    # Bounds are checked with a tolerance value
    tolerance = 1e-5
    # Compute resource usage
    resource_usage = compute_resources(Instance) # dict on resources and time
    # Compare bounds to usage
    for resource_name, resource in Resources.items():
        for time in range(T_max):
            # retrieve bounds values
            upper_bound = resource[MAX_STR][time]
            lower_bound = resource[MIN_STR][time]
            # Consumed value
            worload = resource_usage[resource_name][time]
            # Check max
            if worload > upper_bound + tolerance:
                count += 1
            # Check min
            if worload < lower_bound - tolerance:
                count += 1

    return count

## Exclusions constraints: §4.3 in model description
def check_exclusions(Instance: dict):
    """Check exclusions constraints"""

    count = 0
    # Retrieve Interventions and Exclusions
    Interventions = Instance[INTERVENTIONS_STR]
    Exclusions = Instance[EXCLUSIONS_STR]
    # Assert every exclusion holds
    for exclusion in Exclusions.values():
        # Retrieve exclusion infos
        [intervention_1_name, intervention_2_name, season] = exclusion
        # Retrieve concerned interventions...
        intervention_1 = Interventions[intervention_1_name]
        intervention_2 = Interventions[intervention_2_name]
        # start time should be defined (already checked in scheduled constraint checker)
        if (not START_STR in intervention_1) or (not START_STR in intervention_2):
            continue
        # ... their respective starting times...
        intervention_1_start_time = intervention_1[START_STR]
        intervention_2_start_time = intervention_2[START_STR]
        # ... and their respective deltas (duration)
        intervention_1_delta = int(intervention_1[DELTA_STR][intervention_1_start_time - 1]) # get index in list
        intervention_2_delta = int(intervention_2[DELTA_STR][intervention_2_start_time - 1]) # get index in list
        # Check overlaps for each time step of the season
        for time_str in Instance[SEASONS_STR][season]:
            time = int(time_str)
            if (intervention_1_start_time <= time < intervention_1_start_time + intervention_1_delta) and (intervention_2_start_time <= time < intervention_2_start_time + intervention_2_delta):
                count += 1

    return count

# %%
INSTANCE = read_json(os.path.join("./A_set", INSTANCE_ID + ".json"))

intervention_set = set(int(i.split('_')[1]) for i in list(INSTANCE['Interventions'].keys()))
n_dim = max(intervention_set) + 1
lb = [1 if i in intervention_set else 0 for i in range(n_dim)]
ub = [
    int(INSTANCE['Interventions']['Intervention_' + str(i)]['tmax']) if i in intervention_set 
        else 1
    for i in range(n_dim)
]

precision = [1] * n_dim

def checker(p):
    global n_dim, INSTANCE
    
    list_to_dict(p, INSTANCE)
    
    p_cost = compute_penalty(INSTANCE)
    obj_cost = compute_objective(INSTANCE)
    
    # p_cost = compute_penalty(solution)
    # obj_cost = compute_objective(solution)
    return obj_cost + p_cost

def list_to_dict(solution_list, solution: dict):

    INTERVENTIONS_NAMES = list(solution[INTERVENTIONS_STR].keys())
    for i in range(len(solution_list)):
        t_max = int(solution[INTERVENTIONS_STR][INTERVENTIONS_NAMES[i]][TMAX_STR])

        try:
            s = max(1, int(solution_list[i]))
        except:
            s = t_max
        s = min(s, t_max)
        solution[INTERVENTIONS_STR][INTERVENTIONS_NAMES[i]][START_STR] = s
        solution_list[i] = s
# Out:
# Reading json file ./A_set/A_06.json...
# Done

# %%
def random_neighbourhood(solution: dict, k=1):

    interventions = solution[INTERVENTIONS_STR]
    arr = [[np.random.randint(1, int(interventions[intervention_name][TMAX_STR]) + 1) for intervention_name in interventions.keys()] for i in range(k)]
    return np.array(arr)

# %%
set_run_mode(checker, 'multiprocessing')

from sko.SA import SA

s0 = random_neighbourhood(INSTANCE)
s0 = s0[0]
sa = SA(func=checker, x0=s0, T_max=5, T_min=0.05, L=10, max_stay_counter=10)

# %%
start_time = time.time()
interventions = INSTANCE[INTERVENTIONS_STR]
for iter in range(10000):
    best_x, best_y = sa.run()
    
    end_time = time.time() - start_time
    for i, intervention_name in enumerate(interventions.keys()):
        INSTANCE[INTERVENTIONS_STR][intervention_name][START_STR] = int(best_x[i])
        
    violation = check_schedule(INSTANCE) + check_resources(INSTANCE) + check_exclusions(INSTANCE)
    obj_cost = compute_objective(INSTANCE)
    
    if iter % 20 == 0:
        print("{0} Iterations: {1:.2f}s, objective value {2:.2f} achieved with {3} violations".format(
            10*(iter+1), 
            end_time,
            obj_cost,
            violation
        ))

    if (end_time > TIME_LIMIT): 
        print("Time Limit Exceeded!")
        break
    if (obj_cost <= (1 + GAP)* optimal_value[INSTANCE_ID] and violation == 0):
        print("Optimal Value Achieved!")
        break

# print( 'best_x:', best_x, '\n', 'best_y:', best_y)

Y_history = pd.DataFrame(sa.all_history_Y)
fig, ax = plt.subplots(2, 1)
ax[0].plot(Y_history.index, Y_history.values, '.', color='red')
Y_history.min(axis=1).cummin().plot(kind='line')
plt.show()
# Out:
# 10 Iterations: 1.10s, objective value 920.79 achieved with 60 violations
# 210 Iterations: 2.98s, objective value 953.22 achieved with 49 violations
# 410 Iterations: 4.90s, objective value 963.69 achieved with 48 violations
# 610 Iterations: 6.72s, objective value 989.87 achieved with 40 violations
# 810 Iterations: 8.58s, objective value 974.87 achieved with 36 violations
# 1010 Iterations: 10.42s, objective value 926.64 achieved with 33 violations
# 1210 Iterations: 12.23s, objective value 925.21 achieved with 30 violations
# 1410 Iterations: 14.05s, objective value 898.14 achieved with 30 violations
# 1610 Iterations: 15.86s, objective value 903.54 achieved with 29 violations
# 1810 Iterations: 17.91s, objective value 875.09 achieved with 29 violations
# 2010 Iterations: 19.70s, objective value 875.09 achieved with 29 violations
# 2210 Iterations: 21.47s, objective value 870.99 achieved with 29 violations
# 2410 Iterations: 23.26s, objective value 870.99 achieved with 29 violations
# 2610 Iterations: 25.07s, objective value 870.99 achieved with 29 violations
# 2810 Iterations: 26.95s, objective value 877.67 achieved with 28 violations
# 3010 Iterations: 28.90s, objective value 871.68 achieved with 24 violations
# 3210 Iterations: 30.62s, objective value 871.10 achieved with 24 violations
# 3410 Iterations: 32.34s, objective value 859.56 achieved with 23 violations
# 3610 Iterations: 34.08s, objective value 887.27 achieved with 21 violations
# 3810 Iterations: 35.77s, objective value 887.02 achieved with 21 violations
# 4010 Iterations: 37.52s, objective value 869.20 achieved with 21 violations
# 4210 Iterations: 39.27s, objective value 870.95 achieved with 20 violations
# 4410 Iterations: 40.98s, objective value 867.97 achieved with 20 violations
# 4610 Iterations: 42.70s, objective value 863.47 achieved with 20 violations
# 4810 Iterations: 44.41s, objective value 847.37 achieved with 20 violations
# 5010 Iterations: 46.12s, objective value 842.41 achieved with 19 violations
# 5210 Iterations: 47.81s, objective value 838.07 achieved with 19 violations
# 5410 Iterations: 49.50s, objective value 832.48 achieved with 19 violations
# 5610 Iterations: 51.19s, objective value 831.98 achieved with 19 violations
# 5810 Iterations: 52.89s, objective value 827.23 achieved with 19 violations
# 6010 Iterations: 54.58s, objective value 827.23 achieved with 19 violations
# 6210 Iterations: 56.28s, objective value 823.88 achieved with 19 violations
# 6410 Iterations: 58.00s, objective value 819.81 achieved with 19 violations
# 6610 Iterations: 59.86s, objective value 812.99 achieved with 19 violations
# 6810 Iterations: 61.56s, objective value 812.81 achieved with 18 violations
# 7010 Iterations: 63.27s, objective value 812.56 achieved with 18 violations
# 7210 Iterations: 65.00s, objective value 808.71 achieved with 18 violations
# 7410 Iterations: 66.71s, objective value 808.71 achieved with 18 violations
# 7610 Iterations: 68.46s, objective value 808.51 achieved with 18 violations
# 7810 Iterations: 70.22s, objective value 808.51 achieved with 18 violations
# 8010 Iterations: 71.93s, objective value 806.28 achieved with 18 violations
# 8210 Iterations: 73.70s, objective value 804.55 achieved with 18 violations
# 8410 Iterations: 75.43s, objective value 803.82 achieved with 18 violations
# 8610 Iterations: 77.15s, objective value 801.16 achieved with 18 violations
# 8810 Iterations: 78.87s, objective value 801.16 achieved with 18 violations
# 9010 Iterations: 80.56s, objective value 796.52 achieved with 18 violations
# 9210 Iterations: 82.32s, objective value 788.37 achieved with 18 violations
# 9410 Iterations: 84.09s, objective value 788.30 achieved with 18 violations
# 9610 Iterations: 85.81s, objective value 787.78 achieved with 18 violations
# 9810 Iterations: 87.52s, objective value 787.78 achieved with 18 violations
# 10010 Iterations: 89.23s, objective value 786.56 achieved with 18 violations
# 10210 Iterations: 90.95s, objective value 786.56 achieved with 18 violations
# 10410 Iterations: 92.68s, objective value 784.26 achieved with 18 violations
# 10610 Iterations: 94.40s, objective value 781.96 achieved with 18 violations
# 10810 Iterations: 96.13s, objective value 781.93 achieved with 18 violations
# 11010 Iterations: 97.90s, objective value 781.57 achieved with 18 violations
# 11210 Iterations: 99.73s, objective value 780.26 achieved with 18 violations
# 11410 Iterations: 101.59s, objective value 779.26 achieved with 18 violations
# 11610 Iterations: 103.36s, objective value 778.31 achieved with 18 violations
# 11810 Iterations: 105.09s, objective value 777.48 achieved with 18 violations
# 12010 Iterations: 106.88s, objective value 776.52 achieved with 18 violations
# 12210 Iterations: 108.82s, objective value 776.43 achieved with 18 violations
# 12410 Iterations: 110.72s, objective value 775.03 achieved with 18 violations
# 12610 Iterations: 112.53s, objective value 774.39 achieved with 18 violations
# 12810 Iterations: 114.23s, objective value 769.56 achieved with 18 violations
# 13010 Iterations: 115.94s, objective value 768.05 achieved with 18 violations
# 13210 Iterations: 117.63s, objective value 767.09 achieved with 18 violations
# 13410 Iterations: 119.32s, objective value 761.13 achieved with 17 violations
# 13610 Iterations: 121.00s, objective value 760.16 achieved with 17 violations
# 13810 Iterations: 122.75s, objective value 759.12 achieved with 17 violations
# 14010 Iterations: 124.47s, objective value 758.99 achieved with 17 violations
# 14210 Iterations: 126.22s, objective value 758.49 achieved with 17 violations
# 14410 Iterations: 128.00s, objective value 755.31 achieved with 17 violations
# 14610 Iterations: 129.76s, objective value 755.05 achieved with 17 violations
# 14810 Iterations: 131.46s, objective value 754.58 achieved with 17 violations
# 15010 Iterations: 133.22s, objective value 754.05 achieved with 17 violations
# 15210 Iterations: 135.02s, objective value 752.18 achieved with 17 violations
# 15410 Iterations: 136.77s, objective value 752.11 achieved with 17 violations
# 15610 Iterations: 138.46s, objective value 750.98 achieved with 17 violations
# 15810 Iterations: 140.15s, objective value 751.24 achieved with 16 violations
# 16010 Iterations: 141.93s, objective value 749.97 achieved with 16 violations
# 16210 Iterations: 143.65s, objective value 749.97 achieved with 16 violations
# 16410 Iterations: 145.36s, objective value 749.67 achieved with 16 violations
# 16610 Iterations: 147.15s, objective value 747.68 achieved with 16 violations
# 16810 Iterations: 148.92s, objective value 746.06 achieved with 16 violations
# 17010 Iterations: 150.68s, objective value 746.02 achieved with 16 violations
# 17210 Iterations: 152.41s, objective value 745.68 achieved with 16 violations
# 17410 Iterations: 154.14s, objective value 745.54 achieved with 16 violations
# 17610 Iterations: 155.86s, objective value 745.09 achieved with 16 violations
# 17810 Iterations: 157.60s, objective value 744.06 achieved with 16 violations
# 18010 Iterations: 159.32s, objective value 742.60 achieved with 16 violations
# 18210 Iterations: 161.06s, objective value 735.99 achieved with 16 violations
# 18410 Iterations: 162.86s, objective value 735.90 achieved with 16 violations
# 18610 Iterations: 164.72s, objective value 735.73 achieved with 16 violations
# 18810 Iterations: 166.60s, objective value 734.87 achieved with 16 violations
# 19010 Iterations: 168.47s, objective value 734.87 achieved with 16 violations
# 19210 Iterations: 170.23s, objective value 734.83 achieved with 16 violations
# 19410 Iterations: 171.99s, objective value 734.83 achieved with 16 violations
# 19610 Iterations: 173.71s, objective value 734.83 achieved with 16 violations
# 19810 Iterations: 175.42s, objective value 734.83 achieved with 16 violations
# 20010 Iterations: 177.14s, objective value 734.83 achieved with 16 violations
# 20210 Iterations: 178.87s, objective value 734.83 achieved with 16 violations
# 20410 Iterations: 180.61s, objective value 734.83 achieved with 16 violations
# 20610 Iterations: 182.33s, objective value 734.83 achieved with 16 violations
# 20810 Iterations: 184.04s, objective value 734.83 achieved with 16 violations
# 21010 Iterations: 185.78s, objective value 734.83 achieved with 16 violations
# 21210 Iterations: 187.52s, objective value 734.83 achieved with 16 violations
# 21410 Iterations: 189.23s, objective value 734.83 achieved with 16 violations
# 21610 Iterations: 190.99s, objective value 734.83 achieved with 16 violations
# 21810 Iterations: 192.76s, objective value 734.83 achieved with 16 violations
# 22010 Iterations: 194.50s, objective value 734.83 achieved with 16 violations
# 22210 Iterations: 196.25s, objective value 734.83 achieved with 16 violations
# 22410 Iterations: 198.00s, objective value 734.83 achieved with 16 violations
# 22610 Iterations: 199.77s, objective value 734.83 achieved with 16 violations
# 22810 Iterations: 201.53s, objective value 734.83 achieved with 16 violations
# 23010 Iterations: 203.48s, objective value 734.83 achieved with 16 violations
# 23210 Iterations: 205.21s, objective value 734.83 achieved with 16 violations
# 23410 Iterations: 206.93s, objective value 734.83 achieved with 16 violations
# 23610 Iterations: 208.70s, objective value 734.83 achieved with 16 violations
# 23810 Iterations: 210.43s, objective value 734.83 achieved with 16 violations
# 24010 Iterations: 212.21s, objective value 734.83 achieved with 16 violations
# 24210 Iterations: 214.00s, objective value 734.83 achieved with 16 violations
# 24410 Iterations: 215.89s, objective value 734.83 achieved with 16 violations
# 24610 Iterations: 217.83s, objective value 734.83 achieved with 16 violations
# 24810 Iterations: 219.65s, objective value 734.83 achieved with 16 violations
# 25010 Iterations: 221.45s, objective value 734.83 achieved with 16 violations
# 25210 Iterations: 223.26s, objective value 734.83 achieved with 16 violations
# 25410 Iterations: 225.02s, objective value 734.83 achieved with 16 violations
# 25610 Iterations: 226.78s, objective value 734.83 achieved with 16 violations
# 25810 Iterations: 228.55s, objective value 734.83 achieved with 16 violations
# 26010 Iterations: 230.32s, objective value 734.83 achieved with 16 violations
# 26210 Iterations: 232.13s, objective value 734.83 achieved with 16 violations
# 26410 Iterations: 234.00s, objective value 734.83 achieved with 16 violations
# 26610 Iterations: 235.74s, objective value 734.83 achieved with 16 violations
# 26810 Iterations: 237.54s, objective value 734.83 achieved with 16 violations
# 27010 Iterations: 239.32s, objective value 734.83 achieved with 16 violations
# 27210 Iterations: 241.19s, objective value 734.83 achieved with 16 violations
# 27410 Iterations: 243.05s, objective value 734.83 achieved with 16 violations
# 27610 Iterations: 244.78s, objective value 734.83 achieved with 16 violations
# 27810 Iterations: 246.48s, objective value 734.83 achieved with 16 violations
# 28010 Iterations: 248.22s, objective value 734.83 achieved with 16 violations
# 28210 Iterations: 249.97s, objective value 734.83 achieved with 16 violations
# 28410 Iterations: 251.73s, objective value 734.83 achieved with 16 violations
# 28610 Iterations: 253.46s, objective value 734.83 achieved with 16 violations
# 28810 Iterations: 255.16s, objective value 734.83 achieved with 16 violations
# 29010 Iterations: 256.91s, objective value 734.83 achieved with 16 violations
# 29210 Iterations: 258.64s, objective value 734.83 achieved with 16 violations
# 29410 Iterations: 260.34s, objective value 734.83 achieved with 16 violations
# 29610 Iterations: 262.06s, objective value 734.83 achieved with 16 violations
# 29810 Iterations: 263.77s, objective value 734.83 achieved with 16 violations
# 30010 Iterations: 265.48s, objective value 734.83 achieved with 16 violations
# 30210 Iterations: 267.18s, objective value 734.83 achieved with 16 violations
# 30410 Iterations: 268.88s, objective value 734.83 achieved with 16 violations
# 30610 Iterations: 270.57s, objective value 734.83 achieved with 16 violations
# 30810 Iterations: 272.27s, objective value 734.83 achieved with 16 violations
# 31010 Iterations: 273.95s, objective value 734.83 achieved with 16 violations
# 31210 Iterations: 275.64s, objective value 734.83 achieved with 16 violations
# 31410 Iterations: 277.32s, objective value 734.83 achieved with 16 violations
# 31610 Iterations: 279.00s, objective value 734.83 achieved with 16 violations
# 31810 Iterations: 280.67s, objective value 734.83 achieved with 16 violations
# 32010 Iterations: 282.37s, objective value 734.83 achieved with 16 violations
# 32210 Iterations: 284.08s, objective value 734.83 achieved with 16 violations
# 32410 Iterations: 285.78s, objective value 734.83 achieved with 16 violations
# 32610 Iterations: 287.48s, objective value 734.83 achieved with 16 violations
# 32810 Iterations: 289.19s, objective value 734.83 achieved with 16 violations
# 33010 Iterations: 290.87s, objective value 734.83 achieved with 16 violations
# 33210 Iterations: 292.56s, objective value 734.83 achieved with 16 violations
# 33410 Iterations: 294.24s, objective value 734.83 achieved with 16 violations
# 33610 Iterations: 295.97s, objective value 734.83 achieved with 16 violations
# 33810 Iterations: 297.65s, objective value 734.83 achieved with 16 violations
# 34010 Iterations: 299.33s, objective value 734.83 achieved with 16 violations
# 34210 Iterations: 301.01s, objective value 734.83 achieved with 16 violations
# 34410 Iterations: 302.71s, objective value 734.83 achieved with 16 violations
# 34610 Iterations: 304.40s, objective value 734.83 achieved with 16 violations
# 34810 Iterations: 306.08s, objective value 734.83 achieved with 16 violations
# 35010 Iterations: 307.77s, objective value 734.83 achieved with 16 violations
# 35210 Iterations: 309.44s, objective value 734.83 achieved with 16 violations
# 35410 Iterations: 311.11s, objective value 734.83 achieved with 16 violations
# 35610 Iterations: 312.80s, objective value 734.83 achieved with 16 violations
# 35810 Iterations: 314.48s, objective value 734.83 achieved with 16 violations
# 36010 Iterations: 316.15s, objective value 734.83 achieved with 16 violations
# 36210 Iterations: 317.84s, objective value 734.83 achieved with 16 violations
# 36410 Iterations: 319.51s, objective value 734.83 achieved with 16 violations
# 36610 Iterations: 321.19s, objective value 734.83 achieved with 16 violations
# 36810 Iterations: 323.04s, objective value 734.83 achieved with 16 violations
# 37010 Iterations: 324.74s, objective value 734.83 achieved with 16 violations
# 37210 Iterations: 326.53s, objective value 734.83 achieved with 16 violations
# 37410 Iterations: 328.24s, objective value 734.83 achieved with 16 violations
# 37610 Iterations: 329.97s, objective value 734.83 achieved with 16 violations
# 37810 Iterations: 331.68s, objective value 734.83 achieved with 16 violations
# 38010 Iterations: 333.41s, objective value 734.83 achieved with 16 violations
# 38210 Iterations: 335.15s, objective value 734.83 achieved with 16 violations
# 38410 Iterations: 336.89s, objective value 734.83 achieved with 16 violations
# 38610 Iterations: 338.62s, objective value 734.83 achieved with 16 violations
# 38810 Iterations: 340.32s, objective value 734.83 achieved with 16 violations
# 39010 Iterations: 342.04s, objective value 734.83 achieved with 16 violations
# 39210 Iterations: 343.75s, objective value 734.83 achieved with 16 violations
# 39410 Iterations: 345.44s, objective value 734.83 achieved with 16 violations
# 39610 Iterations: 347.13s, objective value 734.83 achieved with 16 violations
# 39810 Iterations: 348.81s, objective value 734.83 achieved with 16 violations
# 40010 Iterations: 350.59s, objective value 734.83 achieved with 16 violations
# 40210 Iterations: 352.30s, objective value 734.83 achieved with 16 violations
# 40410 Iterations: 353.98s, objective value 734.83 achieved with 16 violations
# 40610 Iterations: 355.68s, objective value 734.83 achieved with 16 violations
# 40810 Iterations: 357.38s, objective value 734.83 achieved with 16 violations
# 41010 Iterations: 359.08s, objective value 734.83 achieved with 16 violations
# 41210 Iterations: 360.79s, objective value 734.83 achieved with 16 violations
# 41410 Iterations: 362.49s, objective value 734.83 achieved with 16 violations
# 41610 Iterations: 364.19s, objective value 734.83 achieved with 16 violations
# 41810 Iterations: 365.89s, objective value 734.83 achieved with 16 violations
# 42010 Iterations: 367.60s, objective value 734.83 achieved with 16 violations
# 42210 Iterations: 369.28s, objective value 734.83 achieved with 16 violations
# 42410 Iterations: 370.97s, objective value 734.83 achieved with 16 violations
# 42610 Iterations: 372.65s, objective value 734.83 achieved with 16 violations
# 42810 Iterations: 374.35s, objective value 734.83 achieved with 16 violations
# 43010 Iterations: 376.06s, objective value 734.83 achieved with 16 violations
# 43210 Iterations: 377.76s, objective value 734.83 achieved with 16 violations
# 43410 Iterations: 379.47s, objective value 734.83 achieved with 16 violations
# 43610 Iterations: 381.18s, objective value 734.83 achieved with 16 violations
# 43810 Iterations: 382.86s, objective value 734.83 achieved with 16 violations
# 44010 Iterations: 384.54s, objective value 734.83 achieved with 16 violations
# 44210 Iterations: 386.21s, objective value 734.83 achieved with 16 violations
# 44410 Iterations: 387.89s, objective value 734.83 achieved with 16 violations
# 44610 Iterations: 389.58s, objective value 734.83 achieved with 16 violations
# 44810 Iterations: 391.28s, objective value 734.83 achieved with 16 violations
# 45010 Iterations: 392.98s, objective value 734.83 achieved with 16 violations
# 45210 Iterations: 394.67s, objective value 734.83 achieved with 16 violations
# 45410 Iterations: 396.36s, objective value 734.83 achieved with 16 violations
# 45610 Iterations: 398.05s, objective value 734.83 achieved with 16 violations
# 45810 Iterations: 399.74s, objective value 734.83 achieved with 16 violations
# 46010 Iterations: 401.42s, objective value 734.83 achieved with 16 violations
# 46210 Iterations: 403.10s, objective value 734.83 achieved with 16 violations
# 46410 Iterations: 404.79s, objective value 734.83 achieved with 16 violations
# 46610 Iterations: 406.47s, objective value 734.83 achieved with 16 violations
# 46810 Iterations: 408.16s, objective value 734.83 achieved with 16 violations
# 47010 Iterations: 409.84s, objective value 734.83 achieved with 16 violations
# 47210 Iterations: 411.51s, objective value 734.83 achieved with 16 violations
# 47410 Iterations: 413.21s, objective value 734.83 achieved with 16 violations
# 47610 Iterations: 414.92s, objective value 734.83 achieved with 16 violations
# 47810 Iterations: 416.69s, objective value 734.83 achieved with 16 violations
# 48010 Iterations: 418.43s, objective value 734.83 achieved with 16 violations
# 48210 Iterations: 420.15s, objective value 734.83 achieved with 16 violations
# 48410 Iterations: 421.94s, objective value 734.83 achieved with 16 violations
# 48610 Iterations: 423.76s, objective value 734.83 achieved with 16 violations
# 48810 Iterations: 425.47s, objective value 734.83 achieved with 16 violations
# 49010 Iterations: 427.20s, objective value 734.83 achieved with 16 violations
# 49210 Iterations: 428.91s, objective value 734.83 achieved with 16 violations
# 49410 Iterations: 430.60s, objective value 734.83 achieved with 16 violations
# 49610 Iterations: 432.28s, objective value 734.83 achieved with 16 violations
# 49810 Iterations: 433.95s, objective value 734.83 achieved with 16 violations
# 50010 Iterations: 435.62s, objective value 734.83 achieved with 16 violations
# 50210 Iterations: 437.29s, objective value 734.83 achieved with 16 violations
# 50410 Iterations: 438.97s, objective value 734.83 achieved with 16 violations
# 50610 Iterations: 440.64s, objective value 734.83 achieved with 16 violations
# 50810 Iterations: 442.32s, objective value 734.83 achieved with 16 violations
# 51010 Iterations: 443.99s, objective value 734.83 achieved with 16 violations
# 51210 Iterations: 445.67s, objective value 734.83 achieved with 16 violations
# 51410 Iterations: 447.34s, objective value 734.83 achieved with 16 violations
# 51610 Iterations: 449.01s, objective value 734.83 achieved with 16 violations
# 51810 Iterations: 450.69s, objective value 734.83 achieved with 16 violations
# 52010 Iterations: 452.36s, objective value 734.83 achieved with 16 violations
# 52210 Iterations: 454.05s, objective value 734.83 achieved with 16 violations
# 52410 Iterations: 455.73s, objective value 734.83 achieved with 16 violations
# 52610 Iterations: 457.41s, objective value 734.83 achieved with 16 violations
# 52810 Iterations: 459.09s, objective value 734.83 achieved with 16 violations
# 53010 Iterations: 460.77s, objective value 734.83 achieved with 16 violations
# 53210 Iterations: 462.46s, objective value 734.83 achieved with 16 violations
# 53410 Iterations: 464.14s, objective value 734.83 achieved with 16 violations
# 53610 Iterations: 465.81s, objective value 734.83 achieved with 16 violations
# 53810 Iterations: 467.51s, objective value 734.83 achieved with 16 violations
# 54010 Iterations: 469.25s, objective value 734.83 achieved with 16 violations
# 54210 Iterations: 471.00s, objective value 734.83 achieved with 16 violations
# 54410 Iterations: 472.75s, objective value 734.83 achieved with 16 violations
# 54610 Iterations: 474.47s, objective value 734.83 achieved with 16 violations
# 54810 Iterations: 476.48s, objective value 734.83 achieved with 16 violations
# 55010 Iterations: 478.70s, objective value 734.83 achieved with 16 violations
# 55210 Iterations: 480.49s, objective value 734.83 achieved with 16 violations
# 55410 Iterations: 482.37s, objective value 734.83 achieved with 16 violations
# 55610 Iterations: 484.19s, objective value 734.83 achieved with 16 violations
# 55810 Iterations: 485.99s, objective value 734.83 achieved with 16 violations
# 56010 Iterations: 487.81s, objective value 734.83 achieved with 16 violations
# 56210 Iterations: 489.58s, objective value 734.83 achieved with 16 violations
# 56410 Iterations: 491.37s, objective value 734.83 achieved with 16 violations
# 56610 Iterations: 493.21s, objective value 734.83 achieved with 16 violations
# 56810 Iterations: 494.99s, objective value 734.83 achieved with 16 violations
# 57010 Iterations: 496.74s, objective value 734.83 achieved with 16 violations
# 57210 Iterations: 498.55s, objective value 734.83 achieved with 16 violations
# 57410 Iterations: 500.47s, objective value 734.83 achieved with 16 violations
# 57610 Iterations: 502.42s, objective value 734.83 achieved with 16 violations
# 57810 Iterations: 504.21s, objective value 734.83 achieved with 16 violations
# 58010 Iterations: 505.99s, objective value 734.83 achieved with 16 violations
# 58210 Iterations: 507.73s, objective value 734.83 achieved with 16 violations
# 58410 Iterations: 509.46s, objective value 734.83 achieved with 16 violations
# 58610 Iterations: 511.17s, objective value 734.83 achieved with 16 violations
# 58810 Iterations: 512.92s, objective value 734.83 achieved with 16 violations
# 59010 Iterations: 514.70s, objective value 734.83 achieved with 16 violations
# 59210 Iterations: 516.59s, objective value 734.83 achieved with 16 violations
# 59410 Iterations: 518.43s, objective value 734.83 achieved with 16 violations
# 59610 Iterations: 520.15s, objective value 734.83 achieved with 16 violations
# 59810 Iterations: 521.90s, objective value 734.83 achieved with 16 violations
# 60010 Iterations: 523.61s, objective value 734.83 achieved with 16 violations
# 60210 Iterations: 525.34s, objective value 734.83 achieved with 16 violations
# 60410 Iterations: 527.09s, objective value 734.83 achieved with 16 violations
# 60610 Iterations: 528.85s, objective value 734.83 achieved with 16 violations
# 60810 Iterations: 530.75s, objective value 734.83 achieved with 16 violations
# 61010 Iterations: 532.48s, objective value 734.83 achieved with 16 violations
# 61210 Iterations: 534.21s, objective value 734.83 achieved with 16 violations
# 61410 Iterations: 535.92s, objective value 734.83 achieved with 16 violations
# 61610 Iterations: 537.66s, objective value 734.83 achieved with 16 violations
# 61810 Iterations: 539.39s, objective value 734.83 achieved with 16 violations
# 62010 Iterations: 541.11s, objective value 734.83 achieved with 16 violations
# 62210 Iterations: 542.93s, objective value 734.83 achieved with 16 violations
# 62410 Iterations: 544.64s, objective value 734.83 achieved with 16 violations
# 62610 Iterations: 546.37s, objective value 734.83 achieved with 16 violations
# 62810 Iterations: 548.27s, objective value 734.83 achieved with 16 violations
# 63010 Iterations: 550.01s, objective value 734.83 achieved with 16 violations
# 63210 Iterations: 551.71s, objective value 734.83 achieved with 16 violations
# 63410 Iterations: 553.44s, objective value 734.83 achieved with 16 violations
# 63610 Iterations: 555.17s, objective value 734.83 achieved with 16 violations
# 63810 Iterations: 556.91s, objective value 734.83 achieved with 16 violations
# 64010 Iterations: 558.67s, objective value 734.83 achieved with 16 violations
# 64210 Iterations: 560.36s, objective value 734.83 achieved with 16 violations
# 64410 Iterations: 562.05s, objective value 734.83 achieved with 16 violations
# 64610 Iterations: 563.74s, objective value 734.83 achieved with 16 violations
# 64810 Iterations: 565.46s, objective value 734.83 achieved with 16 violations
# 65010 Iterations: 567.18s, objective value 734.83 achieved with 16 violations
# 65210 Iterations: 569.00s, objective value 734.83 achieved with 16 violations
# 65410 Iterations: 570.69s, objective value 734.83 achieved with 16 violations
# 65610 Iterations: 572.38s, objective value 734.83 achieved with 16 violations
# 65810 Iterations: 574.09s, objective value 734.83 achieved with 16 violations
# 66010 Iterations: 575.81s, objective value 734.83 achieved with 16 violations
# 66210 Iterations: 577.54s, objective value 734.83 achieved with 16 violations
# 66410 Iterations: 579.30s, objective value 734.83 achieved with 16 violations
# 66610 Iterations: 581.05s, objective value 734.83 achieved with 16 violations
# 66810 Iterations: 582.80s, objective value 734.83 achieved with 16 violations
# 67010 Iterations: 584.55s, objective value 734.83 achieved with 16 violations
# 67210 Iterations: 586.35s, objective value 734.83 achieved with 16 violations
# 67410 Iterations: 588.13s, objective value 734.83 achieved with 16 violations
# 67610 Iterations: 589.88s, objective value 734.83 achieved with 16 violations
# 67810 Iterations: 591.64s, objective value 734.83 achieved with 16 violations
# 68010 Iterations: 593.49s, objective value 734.83 achieved with 16 violations
# 68210 Iterations: 595.29s, objective value 734.83 achieved with 16 violations
# 68410 Iterations: 597.24s, objective value 734.83 achieved with 16 violations
# 68610 Iterations: 599.03s, objective value 734.83 achieved with 16 violations
# 68810 Iterations: 600.84s, objective value 734.83 achieved with 16 violations
# 69010 Iterations: 602.62s, objective value 734.83 achieved with 16 violations
# 69210 Iterations: 604.42s, objective value 734.83 achieved with 16 violations
# 69410 Iterations: 606.19s, objective value 734.83 achieved with 16 violations
# 69610 Iterations: 607.95s, objective value 734.83 achieved with 16 violations
# 69810 Iterations: 610.04s, objective value 734.83 achieved with 16 violations
# 70010 Iterations: 611.82s, objective value 734.83 achieved with 16 violations
# 70210 Iterations: 613.55s, objective value 734.83 achieved with 16 violations
# 70410 Iterations: 615.31s, objective value 734.83 achieved with 16 violations
# 70610 Iterations: 617.05s, objective value 734.83 achieved with 16 violations
# 70810 Iterations: 618.80s, objective value 734.83 achieved with 16 violations
# 71010 Iterations: 620.53s, objective value 734.83 achieved with 16 violations
# 71210 Iterations: 622.20s, objective value 734.83 achieved with 16 violations
# 71410 Iterations: 623.85s, objective value 734.83 achieved with 16 violations
# 71610 Iterations: 625.49s, objective value 734.83 achieved with 16 violations
# 71810 Iterations: 627.28s, objective value 734.83 achieved with 16 violations
# 72010 Iterations: 629.17s, objective value 734.83 achieved with 16 violations
# 72210 Iterations: 630.84s, objective value 734.83 achieved with 16 violations
# 72410 Iterations: 632.48s, objective value 734.83 achieved with 16 violations
# 72610 Iterations: 634.13s, objective value 734.83 achieved with 16 violations
# 72810 Iterations: 635.92s, objective value 734.83 achieved with 16 violations
# 73010 Iterations: 637.59s, objective value 734.83 achieved with 16 violations
# 73210 Iterations: 639.25s, objective value 734.83 achieved with 16 violations
# 73410 Iterations: 640.98s, objective value 734.83 achieved with 16 violations
# 73610 Iterations: 642.74s, objective value 734.83 achieved with 16 violations
# 73810 Iterations: 644.53s, objective value 734.83 achieved with 16 violations
# 74010 Iterations: 646.28s, objective value 734.83 achieved with 16 violations
# 74210 Iterations: 648.02s, objective value 734.83 achieved with 16 violations
# 74410 Iterations: 649.75s, objective value 734.83 achieved with 16 violations
# 74610 Iterations: 651.49s, objective value 734.83 achieved with 16 violations
# 74810 Iterations: 653.24s, objective value 734.83 achieved with 16 violations
# 75010 Iterations: 655.01s, objective value 734.83 achieved with 16 violations
# 75210 Iterations: 656.74s, objective value 734.83 achieved with 16 violations
# 75410 Iterations: 658.51s, objective value 734.83 achieved with 16 violations

# %%
for i in intervention_set:
    print('Intervention_' + str(i), int(best_x[i]))
